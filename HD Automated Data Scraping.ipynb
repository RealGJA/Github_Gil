# %%
from selenium import webdriver
from selenium.webdriver import Chrome
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import time
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 100)

url = "https://www.whatifsports.com/hd/recruiting"
chromedriver = '/Python/Learning/chromedriver'
driver = Chrome(chromedriver)
driver.get(url)

email_input = driver.find_element_by_id("username")
password_input = driver.find_element_by_id("password")
email_input.send_keys("gilalpert4@yahoo.com")
password_input.send_keys("giljoshi123")
password_input.send_keys(Keys.ENTER)
#password_input.submit()

time.sleep(3)

url2 = url + '/TeamRecruitingPool.aspx'
driver.get(url2)


ScoutLvl =  driver.find_element_by_xpath(".//select[@id='ctl00_ctl00_ctl00_ctl00_ctl00_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_ddlScoutingLevel']")
ScoutLvl.send_keys('2')
driver.find_element_by_xpath(".//div[@class='applyButton']/a[@id='ctl00_ctl00_ctl00_ctl00_ctl00_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_btn_Search']").click()

#def scrapdata(driver):
html = driver.page_source
soup = BeautifulSoup(html)
html_content = soup.prettify()
tables = pd.read_html(html_content)
# tables[1]

tables[1].drop([25,26], inplace=True)
tables[1] = tables[1].reset_index()

tempt = tables[2].copy()
tempt.loc[-1] = tables[2].columns.values
tempt.index +=1
tempt.drop([25], inplace=True)
tempt.columns = ['Name']
tempt.sort_index(inplace=True)
tempt = tempt.reset_index()
tempt

CopyTable = pd.DataFrame(tables[1])
CopyTable.columns = CopyTable.columns.get_level_values(1)
CopyTable.insert(1,0,tempt['Name'].iloc[0:])
CopyTable = CopyTable.rename(index=str,columns={0: "Name"})
CopyTable = CopyTable.drop(columns=["Unnamed: 0_level_1"])
CopyTable = CopyTable.drop(columns=["Unnamed: 1_level_1"])
tables[1] = CopyTable
#tables[1]

tables[3].drop([25], inplace=True)
tables[3] = tables[3].reset_index()
#tables[3]

tables[4].drop([25], inplace=True)
tables[4] = tables[4].reset_index()
tables[4] = tables[4].drop(columns=["Unnamed: 1"], axis=1)

players = pd.concat([tables[1],tables[3],tables[4]], sort=False)
players

#tables[1] = tables[1].rename(index=str,columns={0: "Name"})
 
#tables[1] = pd.merge(tables[3], left_on='lkey', right_on='rkey')
#tables[1] = pd.merge(tables[4], left_on='lkey', right_on='rkey')
#tables[1]
    
    #return tables[1]

#scrapdata(driver)


#tables[1].insert(0,0,tempt,allow_duplicates=TRUE)
#tables[1] = tables[1].join(tempt)
#tables[1]['(index, )'] = tables[1]['Name']
#tables[1]['Name']
# Out:
#                       Name  Pos   ST   DU    A  SPD  REB   DE  BLK   LP   PE  \
# 0    0.0     Richard Allen   SG    B    C    A    A    D    A    F    F    A
# 1    1.0     Milton Carter    C    B    C    A    D    A    A    A    A    D
# 2    2.0      David Nguyen   SG    B    B    A    B    C    A    F    B    B
# 3    3.0    John Goodridge   SG    B    C    B    A    F    C    F    C    A
# 4    4.0     Thomas Powell   PF    B    A    A    C    B    A    B    A    D
# 5    5.0    John Jefferson   SF    A    D    A    C    D    A    D    C    D
# 6    6.0   Donald Schuller   PF    B    D    C    C    C    B    D    A    D
# 7    7.0    Marijan Zundel   PF    A    A    A    C    A    A    A    A    D
# 8    8.0    Carlos Hammett   SF    B    B    A    B    C    A    D    B    D
# 9    9.0   Steve McCammack   PF    C    C    B    F    D    B    F    B    F
# 10  10.0       Josh Wilson   PG    B    D    C    B    F    C    F    F    D
# ...

# %%
tables[3]
# Out:
#     index              Name  Unnamed: 1 Pos Lvl  GPA Yrs Att. Pts Schol.  \
# 0       0     Richard Allen         NaN  SG   2  3.0   4        0     No
# 1       1     Milton Carter         NaN   C   2  2.9   4        0     No
# 2       2      David Nguyen         NaN  SG   2  3.0   4        0     No
# 3       3    John Goodridge         NaN  SG   2  3.6   4        0     No
# 4       4     Thomas Powell         NaN  PF   2  3.2   4        0     No
# 5       5    John Jefferson         NaN  SF   2  3.2   4        0     No
# 6       6   Donald Schuller         NaN  PF   2  3.2   4        0     No
# 7       7    Marijan Zundel         NaN  PF   2  3.2   4        0     No
# 8       8    Carlos Hammett         NaN  SF   2  3.1   4        0     No
# 9       9   Steve McCammack         NaN  PF   2  3.0   4        0     No
# 10     10       Josh Wilson         NaN  PG   2  3.1   4        0     No
# 11     11     James Johnson         NaN  SG   2  2.5   4        0     No
# ...

# %%
elem = driver.find_element_by_xpath('//a[@id="ctl00_ctl00_ctl00_ctl00_ctl00_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_lnkNextPage"]')
elem.click()
scrapdata(driver)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-59-5821a452814e> in <module>
# ----> 1 elem = driver.find_element_by_xpath('//a[@id="ctl00_ctl00_ctl00_ctl00_ctl00_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_lnkNextPage"]')
#       2 elem.click()
#       3 scrapdata(driver)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
# ...

# %%
# everything or anything before 

elem = driver.find_element_by_xpath('//*[@class="switchButton right preferenceSwitch"]')
elem.click()
html = driver.page_source
soup = BeautifulSoup(html)
html_content = soup.prettify()
tables = pd.read_html(html_content)
tables[0]
# Out:
#                    0       1
# 0  General CA Search  delete
# 1  Distance Discover  delete
# 2  Distance Discover  delete

# %%
tables[3].drop([25], inplace=True)
tables[3] = tables[3].reset_index()
tables[3]
# Out:
#     index               Name  Unnamed: 1 Pos Lvl  GPA Yrs Att. Pts Schol.  \
# 0       0      Richard Allen         NaN  SG   2  3.0   4        0     No
# 1       1      Milton Carter         NaN   C   2  2.9   4        0     No
# 2       2       David Nguyen         NaN  SG   2  3.0   4        0     No
# 3       3      Thomas Powell         NaN  PF   2  3.2   4        0     No
# 4       4     John Jefferson         NaN  SF   2  3.2   4        0     No
# 5       5     Marijan Zundel         NaN  PF   2  3.2   4        0     No
# 6       6     Robert Higgins         NaN  PG   2  2.8   4        0     No
# 7       7      Philip Norman         NaN   C   2  4.0   4        0     No
# 8       8     John Goodridge         NaN  SG   2  3.6   4        0     No
# 9       9    Donald Schuller         NaN  PF   2  3.2   4        0     No
# 10     10     Carlos Hammett         NaN  SF   2  3.1   4        0     No
# 11     11   Gilbert Mitchell         NaN  SF   2  2.9   4        0     No
# ...

# %%
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', 2000)
    pd.set_option('display.float_format', '{:20,.2f}'.format)
    pd.set_option('display.max_colwidth', -1)
    print(x)
    pd.reset_option('display.max_rows')
    pd.reset_option('display.max_columns')
    pd.reset_option('display.width')
    pd.reset_option('display.float_format')
    pd.reset_option('display.max_colwidth')
print_full(tables[4])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2bb377a3cfde> in <module>
#      11     pd.reset_option('display.float_format')
#      12     pd.reset_option('display.max_colwidth')
# ---> 13 print_full(tables[4])
#
# NameError: name 'tables' is not defined

# %%
tables[4].drop([25], inplace=True)
tables[4] = tables[4].reset_index()
tables[4] = tables[4].drop(columns=["Unnamed: 1"], axis=1)
tables[4]
# Out:
#     index               Name                      PT  \
# 0       0      Richard Allen  Wants to Play  Neutral
# 1       1      Milton Carter        No Preference  -
# 2       2       David Nguyen        No Preference  -
# 3       3      Thomas Powell        No Preference  -
# 4       4     John Jefferson  Wants to Play  Neutral
# 5       5     Marijan Zundel  Wants to Play  Neutral
# 6       6     Robert Higgins        No Preference  -
# 7       7      Philip Norman  Wants to Play  Neutral
# 8       8     John Goodridge        No Preference  -
# 9       9    Donald Schuller  Wants to Play  Neutral
# 10     10     Carlos Hammett        No Preference  -
# 11     11   Gilbert Mitchell        No Preference  -
# 12     12    Steve McCammack  Wants to Play  Neutral
# 13     13      James Heppner  Wants to Play  Neutral
# 14     14        Bruce Erwin        No Preference  -
# 15     15       Roscoe Peltz  Wants to Play  Neutral
# 16     16      Ryan Emberton        No Preference  -
# ...

# %%
tables[1].to_pickle("tables.pk")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ba471fe93c96> in <module>
# ----> 1 tables[1].to_pickle("tables.pk")
#
# NameError: name 'tables' is not defined

# %%
# !dir
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is 3058-8D32
#
#  Directory of C:\Users\User
#
# 04/24/2019  06:38 PM    <DIR>          .
# 04/24/2019  06:38 PM    <DIR>          ..
# 04/15/2019  08:32 PM    <DIR>          .3T
# 02/21/2019  12:52 PM    <DIR>          .anaconda
# 04/15/2019  08:32 PM               983 .bash_history
# 04/15/2019  08:08 PM    <DIR>          .cache
# 01/05/2018  02:13 PM    <DIR>          .casinocoin
# 04/03/2019  05:13 PM    <DIR>          .conda
# 04/24/2019  06:30 PM                43 .condarc
# 04/18/2019  05:08 PM               299 .gitconfig
# 11/17/2018  09:03 AM    <DIR>          .idlerc
# 04/23/2019  08:17 PM    <DIR>          .ipynb_checkpoints
# 11/10/2018  02:21 PM    <DIR>          .ipython
# 04/22/2019  04:24 PM    <DIR>          .jupyter
# 04/16/2019  10:30 PM    <DIR>          .matplotlib
# 07/26/2016  07:36 AM    <DIR>          .oracle_jre_usage
# 12/14/2018  08:45 AM    <DIR>          .PyCharmCE2018.3
# ...

# %%
df = pd.read_pickle("tables.pk")
df
# Out:
#    index               Name Unnamed: 2_level_0 Physical           Defense     \
#                                            Pos       ST DU  A SPD     REB DE
# 0      0      Richard Allen                 SG        B  C  A   A       D  A
# 1      1      Milton Carter                  C        B  C  A   D       A  A
# 2      2       David Nguyen                 SG        B  B  A   B       C  A
# 3      3      Thomas Powell                 PF        B  A  A   C       B  A
# 4      4     John Jefferson                 SF        A  D  A   C       D  A
# 5      5     Marijan Zundel                 PF        A  A  A   C       A  A
# 6      6     Robert Higgins                 PG        A  A  C   B       F  B
# 7      7      Philip Norman                  C        B  B  D   D       A  C
# 8      8     John Goodridge                 SG        B  C  B   A       F  C
# 9      9    Donald Schuller                 PF        B  D  C   C       C  B
# ...

# %%
# !pip install python-dateutil

# %%
df[tables[1],tables[3],tables[4]] = pd.DataFrame([[np.nan, 'tables', 3]], index=df.index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-65ca52bb560d> in <module>
# ----> 1 df[tables[1],tables[3],tables[4]] = pd.DataFrame([[np.nan, 'tables', 3]], index=df.index)
#
# NameError: name 'np' is not defined

# %%
span[@class='nextpage']/a[@id='ctl00_ctl00_ctl00_ctl00_ctl00_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_lnkNextPage']

# %%
tempt = tables[2].copy()
Stored_Name = tempt.loc[0]
tempt2 = tables[2].copy()
tempt2.loc[0] = list(tempt2.columns.values)
tempt2.columns = ['Name']


#tempt.insert(1.0,tempt2)


#tempt.loc[0] = list(tempt.columns.values)
#tables[1]['(index, )'] = tables[1]['Name']
#tables[1]['Name']

# %%
pd.MultiIndex.droplevel(CopyTable, level=0)

# %%
#tables[1].MultiIndex(level=1)
df = pd.DataFrame(tables[1])
df.columns = df.columns.get_level_values(1)
df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-55-bbd32a6876ee> in <module>
#       1 #tables[1].MultiIndex(level=1)
#       2 df = pd.DataFrame(tables[1])
# ----> 3 df.columns = df.columns.get_level_values(1)
#       4 df
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_level_values(self, level)
#    1484         Index(['a', 'b', 'c'], dtype='object')
#    1485         """
# -> 1486         self._validate_index_level(level)
#    1487         return self
#    1488
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _validate_index_level(self, level)
#    1419                 raise IndexError("Too many levels:"
#    1420                                  " Index has only 1 level, not %d" %
# -> 1421                                  (level + 1))
#    1422         elif level != self.name:
# ...

# %%
CopyTable
# Out:
#                      Name  Unnamed: 1_level_1 Pos ST DU  A SPD REB DE  ... PE  \
# 0    0      Richard Allen                 NaN  SG  B  C  A   A   D  A  ...  A
# 1    1      Milton Carter                 NaN   C  B  C  A   D   A  A  ...  D
# 2    2       David Nguyen                 NaN  SG  B  B  A   B   C  A  ...  B
# 3    3      Thomas Powell                 NaN  PF  B  A  A   C   B  A  ...  D
# 4    4     John Jefferson                 NaN  SF  A  D  A   C   D  A  ...  D
# 5    5     Marijan Zundel                 NaN  PF  A  A  A   C   A  A  ...  D
# 6    6     Robert Higgins                 NaN  PG  A  A  C   B   F  B  ...  B
# 7    7      Philip Norman                 NaN   C  B  B  D   D   A  C  ...  F
# 8    8     John Goodridge                 NaN  SG  B  C  B   A   F  C  ...  A
# 9    9    Donald Schuller                 NaN  PF  B  D  C   C   C  B  ...  D
# 10  10     Carlos Hammett                 NaN  SF  B  B  A   B   C  A  ...  D
# ...

# %%
tempt = tables[2].copy()
tempt.loc[-1] = tables[2].columns.values
tempt.index +=1
tempt.drop([25], inplace=True)
tempt.columns = ['Name']
tempt.sort_index(inplace=True)
tempt = tempt.reset_index()
tempt

# %%
tempt.sort_index(inplace=True) 
tempt

# %%
# tables[4].columns['Off.']
# tables[4].loc['Off.']
off = tables[4].iloc[:,6]
deff = tables[4].iloc[:,7]

# %%
off

# %%
tables[1] = tables[1].join(tempt)

# %%
tables[1]['(index, )'] = tables[1]['Name']
tables[1]['Name']

# %%
tables[1]

# %%
tables[1].iloc[:,tables[1]['Unnamed: 2_level_0'] == 'Pos']

# %%
tables[1]['Unnamed: 2_level_0'] == 'Pos'

# %%
#tables[1].columns.droplevel()
tables[2]
list(tempt.columns.values)

# %%
tempt = tables[2].copy()
tempt.loc[0] = list(tempt.columns.values)
tempt.columns = ['Name']
tempt

# %%
tables[2]

# %%
print(ScoutLvl)

# %%
/div[@class='criteriaSection options']/div[@class='criteriaOption']

# %%
 driver.find_element_by_xpath(".//select[@id='ctl00_ctl00_ctl00_ctl00_ctl00_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_ddlScoutingLevel']").get_attribute('textContent')

# %%
 driver.find_element_by_xpath(".//select[@id='ctl00_ctl00_ctl00_ctl00_ctl00_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_ddlScoutingLevel']").get_attribute('textContent')

# %%
 driver.find_element_by_xpath(".//select[@id='ctl00_ctl00_ctl00_ctl00_ctl00_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_ddlScoutingLevel']").click()

# %%
select =  driver.find_element_by_xpath(".//select[@id='ctl00_ctl00_ctl00_ctl00_ctl00_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_ddlScoutingLevel']")
select.send_keys('2')
driver.find_element_by_xpath(".//div[@class='applyButton']/a[@id='ctl00_ctl00_ctl00_ctl00_ctl00_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_btn_Search']").click()

# %%
#div[@class='applyButton']/a[@id='ctl00_ctl00_ctl00_ctl00_ctl00_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_MainContentPlaceHolder_btn_Search']

# %%
from bs4 import BeautifulSoup
from requests import get
html = driver.page_source
soup = BeautifulSoup(html)
soup

# %%
type(soup)

# %%
soup

# %%
html_content = soup.prettify()
html_content

# %%
import pandas as pd
tables = pd.read_html(html_content)
tables[1]

# %%
from selenium import webdriver
from selenium.webdriver import Chrome
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import pandas as pd
import time

url = "https://www.whatifsports.com/hd/recruiting"
chromedriver = '/Python/Learning/chromedriver'
driver = Chrome(chromedriver)
driver.get(url)

email_input = driver.find_element_by_id("username")
password_input = driver.find_element_by_id("password")
email_input.send_keys("gilalpert4@yahoo.com")
password_input.send_keys("giljoshi123")
password_input.send_keys(Keys.ENTER)
#password_input.submit()

time.sleep(3)

url2 = url + '/TeamRecruitingPool.aspx'
driver.get(url2)
