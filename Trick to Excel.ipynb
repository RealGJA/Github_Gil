# %%
import csv
import pandas as pd
from jsonschema import validate
pd.set_option('display.max_columns', 100)

df = pd.read_csv('C:/Users/User/Documents/Plato/organizations.csv')

# %%
df2 = df.sort_values(['rank'], ascending=[True]).head(50000)
df2.head()
# Out:
#                                         uuid                           name  \
# 208545  3718597a-dd39-6661-3630-09cdd43bcac2                      Techstars
# 52311   1ac25206-3b8a-b4a6-48b3-5df4b671e586                         Xiaomi
# 33939   08644a69-76ed-ce2d-afff-b236a22efa69                      Instagram
# 60155   0ab984e9-7413-addd-0b09-7fd5fdef4150  National Institutes of Health
# 91555   da761bfc-adb7-e9b1-b90d-52d436c96e75             Entrepreneur First
#
#                 type                      permalink  \
# 208545  organization                      techstars
# 52311   organization                         xiaomi
# 33939   organization                      instagram
# 60155   organization  national-institutes-of-health
# 91555   organization             entrepreneur-first
#
#                                                    cb_url  rank  \
# 208545  https://www.crunchbase.com/organization/techstars   1.0
# ...

# %%
df2_1 = df2[['status', 'uuid']].groupby(['status' ]).count()
df2_1 = pd.DataFrame(df2_1).reset_index()
df2_1
# Out:
#       status   uuid
# 0   acquired   6077
# 1     closed    944
# 2        ipo   2991
# 3  operating  39988

# %%
df1_1 = df[['status', 'uuid']].groupby(['status' ]).count()
df1_1 = pd.DataFrame(df1_1).reset_index()
df1_1
# Out:
#       status    uuid
# 0   acquired   83306
# 1     closed   33341
# 2        ipo   13663
# 3  operating  626365

# %%
# df2_1.join(df1_1)
df4= pd.concat([df2_1, df1_1], ignore_index=True, axis=1)
df4
# Out:
#            0      1          2       3
# 0   acquired   6077   acquired   83306
# 1     closed    944     closed   33341
# 2        ipo   2991        ipo   13663
# 3  operating  39988  operating  626365

# %%
df4['status'] = df4[1]/df4[3]
df4.index=df4[0]
df4 = df4.drop(df4.columns[[0, 1, 2,3]], axis=1)
df4
# Out:
#              status
# 0
# acquired   0.072948
# closed     0.028313
# ipo        0.218912
# operating  0.063841
